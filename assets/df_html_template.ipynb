# %%
import pandas as pd

# %%
path = "moviesapi_clean.csv"
df = pd.read_csv(path)
df = df.head(100)
df
# Out:
#                                           Title  Year      Rated  Runtime  \
# 0                                        Avatar  2009      PG-13      162
# 1      Pirates of the Caribbean: At World's End  2007      PG-13      169
# 2                                       Spectre  2015      PG-13      148
# 3                         The Dark Knight Rises  2012      PG-13      164
# 4                                   John Carter  2012      PG-13      132
# 5                                  Spider-Man 3  2007      PG-13      139
# 6                                       Tangled  2010         PG      100
# 7                       Avengers: Age of Ultron  2015      PG-13      141
# 8        Harry Potter and the Half-Blood Prince  2009         PG      153
# 9            Batman v Superman: Dawn of Justice  2016      PG-13      151
# 10                             Superman Returns  2006      PG-13      154
# 11                            Quantum of Solace  2008      PG-13      106
# ...

# %%
html = df.to_html(classes=["table-borderless", "table-striped", "table-hover"])
print(html)
# Out:
# <table border="1" class="dataframe table-borderless table-striped table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Title</th>
#       <th>Year</th>
#       <th>Rated</th>
#       <th>Runtime</th>
#       <th>Genre</th>
#       <th>Director</th>
#       <th>Writer</th>
#       <th>Language</th>
#       <th>Country</th>
#       <th>Awards</th>
#       <th>IMDB Rating</th>
#       <th>Revenue</th>
#       <th>Budget</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Avatar</td>
#       <td>2009</td>
#       <td>PG-13</td>
#       <td>162</td>
#       <td>Action, Adventure, Fantasy, Sci-Fi</td>
#       <td>James Cameron</td>
#       <td>James Cameron</td>
#       <td>English, Spanish</td>
#       <td>UK, USA</td>
#       <td>Won 3 Oscars. Another 85 wins &amp; 128 nominations.</td>
#       <td>7.8</td>
#       <td>2787965087</td>
#       <td>237000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...
